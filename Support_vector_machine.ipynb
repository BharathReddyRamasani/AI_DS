# %% [markdown]
# <a href="https://colab.research.google.com/github/BharathReddyRamasani/AI_DS/blob/main/Support_vector_machine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/heart.csv")
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0
# 5   0     2       1
# 6   3     1       0
# 7   1     3       0
# 8   0     3       0
# 9   2     2       0

# %%
df.dropna(inplace=True)
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0
# 5   0     2       1
# 6   3     1       0
# 7   1     3       0
# 8   0     3       0
# 9   2     2       0

# %%
from sklearn.preprocessing import LabelEncoder
label_encoders={}
for col in df.select_dtypes(include=['object']).columns:
  le=LabelEncoder()
  df[col]=le.fit_transform(df[col])
  label_encoders[col]=le

# %%
x=df.drop(columns=['target'])
y=df['target']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)
#

# %%
from sklearn.svm import SVC
svm_linear=SVC(kernel='linear',C=1)
svm_linear.fit(x_train,y_train)
y_pred=svm_linear.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,classification_report
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy:",accuracy)
cm=classification_report(y_test,y_pred)
print("Classification Report:\n",cm)
# Out:
# Accuracy: 0.8146341463414634
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.71      0.79       102
#            1       0.76      0.92      0.83       103
#
#     accuracy                           0.81       205
#    macro avg       0.83      0.81      0.81       205
# weighted avg       0.83      0.81      0.81       205

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
print("Confusion Matrix:\n",cm)
# Out:
# Confusion Matrix:
#  [[72 30]
#  [ 8 95]]

# %%
from sklearn.svm import SVC
svm_linear=SVC(kernel='poly',C=1,degree=3)
svm_linear.fit(x_train,y_train)
y_pred=svm_linear.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,classification_report
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy:",accuracy)
cm=classification_report(y_test,y_pred)
print("Classification Report:\n",cm)
# Out:
# Accuracy: 0.9073170731707317
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.83      0.90       102
#            1       0.86      0.98      0.91       103
#
#     accuracy                           0.91       205
#    macro avg       0.92      0.91      0.91       205
# weighted avg       0.92      0.91      0.91       205

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
print("Confusion Matrix:\n",cm)
# Out:
# Confusion Matrix:
#  [[ 85  17]
#  [  2 101]]

# %%
from sklearn.svm import SVC
svm_linear=SVC(kernel='rbf',C=1)
svm_linear.fit(x_train,y_train)
y_pred=svm_linear.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,classification_report
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy:",accuracy)
cm=classification_report(y_test,y_pred)
print("Classification Report:\n",cm)
# Out:
# Accuracy: 0.8878048780487805
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.83      0.88       102
#            1       0.85      0.94      0.89       103
#
#     accuracy                           0.89       205
#    macro avg       0.89      0.89      0.89       205
# weighted avg       0.89      0.89      0.89       205

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
print("Confusion Matrix:\n",cm)
# Out:
# Confusion Matrix:
#  [[85 17]
#  [ 6 97]]

# %% [markdown]
# new datzset

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/train_u6lujuX_CVtuZ9i.csv")
df.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
# 6             2333             1516.0        95.0             360.0
# 7             3036             2504.0       158.0             360.0
# 8             4006             1526.0       168.0             360.0
# 9            12841            10968.0       349.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y
# 5             1.0         Urban           Y
# 6             1.0         Urban           Y
# 7             0.0     Semiurban           N
# 8             1.0         Urban           Y
# 9             1.0     Semiurban           N

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df['Gender']=df['Gender'].fillna(df['Gender'].mode()[0])
df['Married']=df['Married'].fillna(df['Married'].mode()[0])
df['Dependents']=df['Dependents'].fillna(df['Dependents'].mode()[0])
df['Self_Employed']=df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])
df['LoanAmount']=df['LoanAmount'].fillna(df['LoanAmount'].mean())
df['Loan_Amount_Term']=df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean())
df['Credit_History']=df['Credit_History'].fillna(df['Credit_History'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df.head(15)
# Out:
#      Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0   LP001002   Male      No          0      Graduate            No
# 1   LP001003   Male     Yes          1      Graduate            No
# 2   LP001005   Male     Yes          0      Graduate           Yes
# 3   LP001006   Male     Yes          0  Not Graduate            No
# 4   LP001008   Male      No          0      Graduate            No
# 5   LP001011   Male     Yes          2      Graduate           Yes
# 6   LP001013   Male     Yes          0  Not Graduate            No
# 7   LP001014   Male     Yes         3+      Graduate            No
# 8   LP001018   Male     Yes          2      Graduate            No
# 9   LP001020   Male     Yes          1      Graduate            No
# 10  LP001024   Male     Yes          2      Graduate            No
# 11  LP001027   Male     Yes          2      Graduate            No
# 12  LP001028   Male     Yes          2      Graduate            No
# 13  LP001029   Male      No          0      Graduate            No
# 14  LP001030   Male     Yes          2      Graduate            No
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              5849                0.0  146.412162             360.0
# 1              4583             1508.0  128.000000             360.0
# 2              3000                0.0   66.000000             360.0
# 3              2583             2358.0  120.000000             360.0
# 4              6000                0.0  141.000000             360.0
# 5              5417             4196.0  267.000000             360.0
# 6              2333             1516.0   95.000000             360.0
# 7              3036             2504.0  158.000000             360.0
# 8              4006             1526.0  168.000000             360.0
# 9             12841            10968.0  349.000000             360.0
# 10             3200              700.0   70.000000             360.0
# 11             2500             1840.0  109.000000             360.0
# 12             3073             8106.0  200.000000             360.0
# 13             1853             2840.0  114.000000             360.0
# 14             1299             1086.0   17.000000             120.0
#
#     Credit_History Property_Area Loan_Status
# 0              1.0         Urban           Y
# 1              1.0         Rural           N
# 2              1.0         Urban           Y
# 3              1.0         Urban           Y
# 4              1.0         Urban           Y
# 5              1.0         Urban           Y
# 6              1.0         Urban           Y
# 7              0.0     Semiurban           N
# 8              1.0         Urban           Y
# 9              1.0     Semiurban           N
# 10             1.0         Urban           Y
# 11             1.0         Urban           Y
# 12             1.0         Urban           Y
# 13             1.0         Rural           N
# 14             1.0         Urban           Y

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.boxplot(df['LoanAmount'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x785cae711c70>,
#   <matplotlib.lines.Line2D at 0x785cae713080>],
#  'caps': [<matplotlib.lines.Line2D at 0x785cae7133b0>,
#   <matplotlib.lines.Line2D at 0x785cae7135f0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x785caeb01d00>],
#  'medians': [<matplotlib.lines.Line2D at 0x785cae7138f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x785cae713bc0>],
#  'means': []}

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.boxplot(df['Loan_Amount_Term'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x785cae76bec0>,
#   <matplotlib.lines.Line2D at 0x785cae7981d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x785cae7984a0>,
#   <matplotlib.lines.Line2D at 0x785cae798710>],
#  'boxes': [<matplotlib.lines.Line2D at 0x785cae8685c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x785cae7989e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x785caeaf7f20>],
#  'means': []}

# %%
plt.boxplot(df['Credit_History'])
#
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x785cae5da570>,
#   <matplotlib.lines.Line2D at 0x785cae5da840>],
#  'caps': [<matplotlib.lines.Line2D at 0x785cae5daab0>,
#   <matplotlib.lines.Line2D at 0x785cae5dad20>],
#  'boxes': [<matplotlib.lines.Line2D at 0x785cae5da300>],
#  'medians': [<matplotlib.lines.Line2D at 0x785cae5daed0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x785cae5db170>],
#  'means': []}

# %%
plt.boxplot(df['ApplicantIncome'])
#
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x785cae640d10>,
#   <matplotlib.lines.Line2D at 0x785cae641010>],
#  'caps': [<matplotlib.lines.Line2D at 0x785cae641280>,
#   <matplotlib.lines.Line2D at 0x785cae6415b0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x785cae7126f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x785cae641850>],
#  'fliers': [<matplotlib.lines.Line2D at 0x785cae641af0>],
#  'means': []}

# %%
plt.boxplot(df['CoapplicantIncome'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x785cae6a96a0>,
#   <matplotlib.lines.Line2D at 0x785cae6a9970>],
#  'caps': [<matplotlib.lines.Line2D at 0x785cae6a9c10>,
#   <matplotlib.lines.Line2D at 0x785cae6a9eb0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x785cae6a9460>],
#  'medians': [<matplotlib.lines.Line2D at 0x785cae6aa090>],
#  'fliers': [<matplotlib.lines.Line2D at 0x785cae6aa300>],
#  'means': []}

# %%
df["LoanAmount_log"] = np.log1p(df["LoanAmount"])

# %%
df["Loan_Amount_Term"] = df["Loan_Amount_Term"].fillna(360)

# %%
df["ApplicantIncome_log"] = np.log1p(df["ApplicantIncome"])

# %%
df["CoapplicantIncome_log"] = np.log1p(df["CoapplicantIncome"])

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  614.000000        614.000000
# mean       5403.459283        1621.245798  146.412162        342.000000
# std        6109.041673        2926.248369   84.037468         64.372489
# min         150.000000           0.000000    9.000000         12.000000
# 25%        2877.500000           0.000000  100.250000        360.000000
# 50%        3812.500000        1188.500000  129.000000        360.000000
# 75%        5795.000000        2297.250000  164.750000        360.000000
# max       81000.000000       41667.000000  700.000000        480.000000
#
#        Credit_History  LoanAmount_log  ApplicantIncome_log  \
# count      614.000000      614.000000           614.000000
# mean         0.855049        4.870872             8.341510
# std          0.352339        0.491376             0.645035
# min          0.000000        2.302585             5.017280
# 25%          1.000000        4.617584             7.965024
# 50%          1.000000        4.867534             8.246303
# 75%          1.000000        5.110477             8.664922
# max          1.000000        6.552508            11.302217
#
#        CoapplicantIncome_log
# count             614.000000
# mean                4.290129
# std                 3.875873
# min                 0.000000
# 25%                 0.000000
# 50%                 7.081125
# 75%                 7.739897
# max                10.637489

# %%
df[[
    "ApplicantIncome",
    "CoapplicantIncome",
    "LoanAmount",
    "Loan_Amount_Term",
    "Credit_History"
]].corr()
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.116605    0.565620
# CoapplicantIncome        -0.116605           1.000000    0.187828
# LoanAmount                0.565620           0.187828    1.000000
# Loan_Amount_Term         -0.045242          -0.059675    0.038801
# Credit_History           -0.018615           0.011134   -0.001431
#
#                    Loan_Amount_Term  Credit_History
# ApplicantIncome           -0.045242       -0.018615
# CoapplicantIncome         -0.059675        0.011134
# LoanAmount                 0.038801       -0.001431
# Loan_Amount_Term           1.000000        0.000432
# Credit_History             0.000432        1.000000

# %%
df[[
    "ApplicantIncome_log",
    "CoapplicantIncome_log",
    "LoanAmount_log",
    "Loan_Amount_Term",
    "Credit_History"
]].corr()
# Out:
#                        ApplicantIncome_log  CoapplicantIncome_log  \
# ApplicantIncome_log               1.000000              -0.368258
# CoapplicantIncome_log            -0.368258               1.000000
# LoanAmount_log                    0.492560               0.130524
# Loan_Amount_Term                 -0.030741               0.013613
# Credit_History                    0.013482               0.008274
#
#                        LoanAmount_log  Loan_Amount_Term  Credit_History
# ApplicantIncome_log          0.492560         -0.030741        0.013482
# CoapplicantIncome_log        0.130524          0.013613        0.008274
# LoanAmount_log               1.000000          0.085940       -0.019208
# Loan_Amount_Term             0.085940          1.000000        0.000432
# Credit_History              -0.019208          0.000432        1.000000

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    confusion_matrix,
    classification_report
)

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History Property_Area Loan_Status  LoanAmount_log  \
# 0             1.0         Urban           Y        4.993232
# 1             1.0         Rural           N        4.859812
# 2             1.0         Urban           Y        4.204693
# 3             1.0         Urban           Y        4.795791
# 4             1.0         Urban           Y        4.955827
#
#    ApplicantIncome_log  CoapplicantIncome_log
# 0             8.674197               0.000000
# 1             8.430327               7.319202
# 2             8.006701               0.000000
# 3             7.857094               7.765993
# 4             8.699681               0.000000

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

# ----------------------------------
# Encode categorical columns FIRST
# ----------------------------------
label_encoders = {}

for col in df.select_dtypes(include=['object']).columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# ----------------------------------
# Feature / Target split AFTER encoding
# ----------------------------------
X = df.drop("Loan_Status", axis=1)
y = df["Loan_Status"]

# ----------------------------------
# Train-test split
# ----------------------------------
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42, stratify=y
)

# ----------------------------------
# Scaling
# ----------------------------------
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# IMPORTANT: same variable name
svm_linear = SVC(kernel='linear', C=1)

svm_linear.fit(X_train, y_train)

# FIXED HERE (X_test, not x_test)
y_pred = svm_linear.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)
# Out:
# Accuracy: 0.8571428571428571
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.56      0.71        48
#            1       0.83      0.99      0.91       106
#
#     accuracy                           0.86       154
#    macro avg       0.90      0.78      0.81       154
# weighted avg       0.87      0.86      0.84       154
#
# Confusion Matrix:
#  [[ 27  21]
#  [  1 105]]

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# IMPORTANT: same variable name
svm_linear = SVC(kernel='poly', C=1)

svm_linear.fit(X_train, y_train)

# FIXED HERE (X_test, not x_test)
y_pred = svm_linear.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)
# Out:
# Accuracy: 0.8506493506493507
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.60      0.72        48
#            1       0.84      0.96      0.90       106
#
#     accuracy                           0.85       154
#    macro avg       0.86      0.78      0.81       154
# weighted avg       0.85      0.85      0.84       154
#
# Confusion Matrix:
#  [[ 29  19]
#  [  4 102]]

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# IMPORTANT: same variable name
svm_linear = SVC(kernel='rbf', C=1)

svm_linear.fit(X_train, y_train)

# FIXED HERE (X_test, not x_test)
y_pred = svm_linear.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)
# Out:
# Accuracy: 0.8571428571428571
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.56      0.71        48
#            1       0.83      0.99      0.91       106
#
#     accuracy                           0.86       154
#    macro avg       0.90      0.78      0.81       154
# weighted avg       0.87      0.86      0.84       154
#
# Confusion Matrix:
#  [[ 27  21]
#  [  1 105]]
